# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
df['survived'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
df['survived'].value_counts(normalize = True)
# Out:
# 0    0.618029
# 1    0.381971
# Name: survived, dtype: float64

# %%
df.isnull().sum(axis = 0)
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           264
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df['age'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
df[df['age'].isnull()]
# Out:
#       pclass  survived                                           name     sex  \
# 9          1         0                        Artagaveytia, Mr. Ramon    male
# 15         1         0                            Baumann, Mr. John D    male
# 37         1         1  Bradley, Mr. George ("George Arthur Brayton")    male
# 40         1         0                      Brewe, Dr. Arthur Jackson    male
# 46         1         0                          Cairns, Mr. Alexander    male
# ...      ...       ...                                            ...     ...
# 1293       3         0              Williams, Mr. Howard Hugh "Harry"    male
# 1297       3         0                         Wiseman, Mr. Phillippe    male
# 1302       3         0                              Yousif, Mr. Wazli    male
# 1303       3         0                          Yousseff, Mr. Gerious    male
# 1305       3         0                          Zabour, Miss. Thamine  female
#
#       age  sibsp  parch      ticket     fare cabin embarked boat  body  \
# 9     NaN      0      0    PC 17609  49.5042   NaN        C  NaN  22.0
# 15    NaN      0      0    PC 17318  25.9250   NaN        S  NaN   NaN
# 37    NaN      0      0      111427  26.5500   NaN        S    9   NaN
# 40    NaN      0      0      112379  39.6000   NaN        C  NaN   NaN
# 46    NaN      0      0      113798  31.0000   NaN        S  NaN   NaN
# ...   ...    ...    ...         ...      ...   ...      ...  ...   ...
# 1293  NaN      0      0    A/5 2466   8.0500   NaN        S  NaN   NaN
# 1297  NaN      0      0  A/4. 34244   7.2500   NaN        S  NaN   NaN
# 1302  NaN      0      0        2647   7.2250   NaN        C  NaN   NaN
# 1303  NaN      0      0        2627  14.4583   NaN        C  NaN   NaN
# 1305  NaN      1      0        2665  14.4542   NaN        C  NaN   NaN
#
#                 home.dest
# 9     Montevideo, Uruguay
# 15           New York, NY
# 37        Los Angeles, CA
# 40       Philadelphia, PA
# 46                    NaN
# ...                   ...
# 1293                  NaN
# 1297                  NaN
# 1302                  NaN
# 1303                  NaN
# 1305                  NaN
#
# [264 rows x 14 columns]

# %%
df[df['age'].isnull()]['age']
# Out:
# 9      NaN
# 15     NaN
# 37     NaN
# 40     NaN
# 46     NaN
#         ..
# 1293   NaN
# 1297   NaN
# 1302   NaN
# 1303   NaN
# 1305   NaN
# Name: age, Length: 264, dtype: float64

# %%
df['age'].mean()
# Out:
# 29.841786315789474

# %%
import numpy as np

df['age'] = np.where(df['age'].isnull(), df['age'].mean(), df['age'])

# %%
df.groupby('survived')['age'].mean()
# Out:
# survived
# 0    30.329252
# 1    29.053068
# Name: age, dtype: float64

# %%
df.groupby('survived')['age'].agg(['mean', 'count'])
# Out:
#                mean  count
# survived
# 0         30.329252    809
# 1         29.053068    500
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['count'].plot(kind='hist', bins=20, title='count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='mean', y='count', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['mean'].plot(kind='line', figsize=(8, 4), title='mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4['count'].plot(kind='line', figsize=(8, 4), title='count')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.groupby(['survived', 'embarked'])['age'].agg(['mean', 'count'])
# Out:
#                         mean  count
# survived embarked
# 0        C         32.583444    120
#          Q         30.010823     79
#          S         29.927043    610
# 1        C         30.893792    150
#          Q         28.161259     44
#          S         28.136084    304

# %%
survived = df[['survived', 'embarked', 'age']].replace({0: 'Did Not Survive', 1: 'Survived'})
survived
# Out:
#              survived embarked        age
# 0            Survived        S       29.0
# 1            Survived        S     0.9167
# 2     Did Not Survive        S        2.0
# 3     Did Not Survive        S       30.0
# 4     Did Not Survive        S       25.0
# ...               ...      ...        ...
# 1304  Did Not Survive        C       14.5
# 1305  Did Not Survive        C  29.841786
# 1306  Did Not Survive        C       26.5
# 1307  Did Not Survive        C       27.0
# 1308  Did Not Survive        S       29.0
#
# [1309 rows x 3 columns]

# %%
survived = df[['survived', 'embarked', 'age']].replace({'survived':
                                                        {0: 'Did Not Survive', 1: 'Survived'}
                                                        })
survived
# Out:
#              survived embarked        age
# 0            Survived        S  29.000000
# 1            Survived        S   0.916700
# 2     Did Not Survive        S   2.000000
# 3     Did Not Survive        S  30.000000
# 4     Did Not Survive        S  25.000000
# ...               ...      ...        ...
# 1304  Did Not Survive        C  14.500000
# 1305  Did Not Survive        C  29.841786
# 1306  Did Not Survive        C  26.500000
# 1307  Did Not Survive        C  27.000000
# 1308  Did Not Survive        S  29.000000
#
# [1309 rows x 3 columns]

# %%
survived.groupby(['survived', 'embarked'])['age'].agg(['mean', 'count'])
# Out:
#                                mean  count
# survived        embarked
# Did Not Survive C         32.583444    120
#                 Q         30.010823     79
#                 S         29.927043    610
# Survived        C         30.893792    150
#                 Q         28.161259     44
#                 S         28.136084    304

# %%
df['fare'].mean()
# Out:
# 33.29547928134557

# %%
df['fare'].median()
# Out:
# 14.4542

# %%
df['fare'].describe()
# Out:
# count    1308.000000
# mean       33.295479
# std        51.758668
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: fare, dtype: float64

# %%
pd.cut(df['age'], bins = 3)
# Out:
# 0       (26.778, 53.389]
# 1       (0.0869, 26.778]
# 2       (0.0869, 26.778]
# 3       (26.778, 53.389]
# 4       (0.0869, 26.778]
#               ...
# 1304    (0.0869, 26.778]
# 1305    (26.778, 53.389]
# 1306    (0.0869, 26.778]
# 1307    (26.778, 53.389]
# 1308    (26.778, 53.389]
# Name: age, Length: 1309, dtype: category
# Categories (3, interval[float64, right]): [(0.0869, 26.778] < (26.778, 53.389] < (53.389, 80.0]]

# %%
df['age_bracket'] = pd.cut(df['age'], bins = 3, labels = ['Low', 'Medium', 'High'])
df['age_bracket'].value_counts()
# Out:
# Medium    759
# Low       474
# High       76
# Name: age_bracket, dtype: int64

# %%
df.pivot_table(index = ['embarked'], columns = ['sex'], values = ['survived'], aggfunc = 'mean')
# Out:
#           survived
# sex         female      male
# embarked
# C         0.902655  0.305732
# Q         0.616667  0.111111
# S         0.680412  0.170144

# %%
df.pivot_table(index = ['embarked'], columns = ['sex'], values = ['survived'], aggfunc = 'mean', margins = True)
# Out:
#           survived
# sex         female      male       All
# embarked
# C         0.902655  0.305732  0.555556
# Q         0.616667  0.111111  0.357724
# S         0.680412  0.170144  0.332604
# All       0.726293  0.190985  0.381025

# %%
df.pivot_table()
